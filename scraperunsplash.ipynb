# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from datetime import datetime
import os
import csv
import time
import pandas as pd

# %%
CATEGORIES = open('categories.txt').readlines()
CATEGORIES = [x.strip() for x in CATEGORIES]
OUTPUT_DIR = 'images'
CSV_LINK_FILE = 'image_links.csv'
MAX_IMAGES_PER_CATEGORY = 500

os.makedirs(OUTPUT_DIR, exist_ok=True)  
for category in CATEGORIES:
    category_dir = os.path.join(OUTPUT_DIR, category)
    os.makedirs(category_dir, exist_ok=True)  # Create the category folder if it doesn't exist
    print(f"Created folder: {category_dir}")
# Out:
# Created folder: images\person
# Created folder: images\bicycle
# Created folder: images\car
# Created folder: images\motorbike
# Created folder: images\aeroplane
# Created folder: images\bus
# Created folder: images\train
# Created folder: images\truck
# Created folder: images\boat
# Created folder: images\traffic
# Created folder: images\light
# Created folder: images\fire hydrant
# Created folder: images\stop sign
# Created folder: images\parking meter
# Created folder: images\bench
# Created folder: images\bird
# Created folder: images\cat
# Created folder: images\dog
# Created folder: images\horse
# Created folder: images\sheep
# Created folder: images\cow
# Created folder: images\elephant
# Created folder: images\bear
# Created folder: images\zebra
# Created folder: images\giraffe
# Created folder: images\backpack
# Created folder: images\umbrella
# Created folder: images\handbag
# Created folder: images\tie
# Created folder: images\suitcase
# Created folder: images\frisbee
# Created folder: images\skis
# Created folder: images\snowboard
# Created folder: images\sports ball
# Created folder: images\kite
# Created folder: images\baseball bat
# Created folder: images\baseball glove
# Created folder: images\skateboard
# Created folder: images\surfboard
# Created folder: images\tennis racket
# Created folder: images\bottle
# Created folder: images\wine glass
# Created folder: images\cup
# Created folder: images\fork
# Created folder: images\knife
# Created folder: images\spoon
# Created folder: images\bowl
# Created folder: images\banana
# Created folder: images\apple
# Created folder: images\sandwich
# Created folder: images\orange
# Created folder: images\broccoli
# Created folder: images\carrot
# Created folder: images\hot dog
# Created folder: images\pizza
# Created folder: images\donut
# Created folder: images\cake
# Created folder: images\chair
# Created folder: images\sofa
# Created folder: images\potted plant
# Created folder: images\bed
# Created folder: images\dining table
# Created folder: images\toilet
# Created folder: images\tvmonitor
# Created folder: images\laptop
# Created folder: images\mouse
# Created folder: images\remote
# Created folder: images\keyboard
# Created folder: images\cell phone
# Created folder: images\microwave
# Created folder: images\oven
# Created folder: images\toaster
# Created folder: images\sink
# Created folder: images\refrigerator
# Created folder: images\book
# Created folder: images\clock
# Created folder: images\vase
# Created folder: images\scissors
# Created folder: images\teddy bear
# Created folder: images\hair drier
# Created folder: images\toothbrush

# %%
def scroll_to_bottom(driver, scroll_times=15, delay=0.25):
    for i in range(scroll_times):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(delay)

        try:
            load_more_button = driver.find_element("css selector", "button.cDy10.vbbXa.XKj1X.aZVYw.vqRTY.vGtHf.s5zyR.nwXgM.pYP1f")
            if load_more_button.is_displayed():
                load_more_button.click()
                print(f"Clicked 'Load more' on scroll {i+1}")
                time.sleep(delay)
        except Exception as e:
            print(f"No 'Load more' button after scroll {i+1} or already clicked.")

        print(f"Scrolled {i+1} times.")

# %%
def get_unsplash_image_urls(query):
    options = webdriver.ChromeOptions()
    options.add_argument('--headless=new')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    existing_urls = pd.read_csv("image_metadata.csv")['url'].tolist()

    search_url = f"https://unsplash.com/s/photos/{query}"
    print(f"Scraping URL: {search_url}")
    driver.get(search_url)
    scroll_to_bottom(driver)

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    image_elements = soup.find_all("img", {"data-testid": "photo-grid-masonry-img"})
    image_urls = [img.get("src") for img in image_elements if img.get("src")]
    print(f"Found {len(image_urls)} image URLs.")
    return image_urls

# %%
def save_links_to_csv(category, urls):
    new_rows = []
    if os.path.exists(CSV_LINK_FILE):
        existing_df = pd.read_csv(CSV_LINK_FILE)
        existing_urls = set(existing_df['url'])
    else:
        existing_df = pd.DataFrame()
        existing_urls = set()

    for url in urls:
        if url not in existing_urls:
            new_rows.append({
                "category": category,
                "url": url,
                "source": "Wikimedia Commons",
                "timestamp": datetime.now().isoformat(),
                "downloaded": "False"
            })

    if not new_rows:
        print("No new unique URLs to add.")
        return

    df = pd.DataFrame(new_rows)

    if not os.path.exists(CSV_LINK_FILE):
        df.to_csv(CSV_LINK_FILE, index=False)
    else:
        existing_df = pd.read_csv(CSV_LINK_FILE)
        combined_df = pd.concat([existing_df, df])
        combined_df.drop_duplicates(subset=['url'], inplace=True)
        combined_df.to_csv(CSV_LINK_FILE, index=False)

def scrape_images():
    for category in CATEGORIES:
        print(f"Scraping category: {category}")
        urls = get_unsplash_image_urls(category)
        print(f"Found {len(urls)} image URLs for category: {category}")
        save_links_to_csv(category, urls)

# %%
scrape_images()
# Out:
# Scraping category: person
# Scraping URL: https://unsplash.com/s/photos/person
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: person
# No new unique URLs to add.
# Scraping category: bicycle
# Scraping URL: https://unsplash.com/s/photos/bicycle
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: bicycle
# Scraping category: car
# Scraping URL: https://unsplash.com/s/photos/car
# No 'Load more' button after scroll 1 or already clicked.
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 299 image URLs.
# Found 299 image URLs for category: car
# Scraping category: motorbike
# Scraping URL: https://unsplash.com/s/photos/motorbike
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 320 image URLs.
# Found 320 image URLs for category: motorbike
# Scraping category: aeroplane
# Scraping URL: https://unsplash.com/s/photos/aeroplane
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: aeroplane
# Scraping category: bus
# Scraping URL: https://unsplash.com/s/photos/bus
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 260 image URLs.
# Found 260 image URLs for category: bus
# Scraping category: train
# Scraping URL: https://unsplash.com/s/photos/train
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: train
# Scraping category: truck
# Scraping URL: https://unsplash.com/s/photos/truck
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 320 image URLs.
# Found 320 image URLs for category: truck
# Scraping category: boat
# Scraping URL: https://unsplash.com/s/photos/boat
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 260 image URLs.
# Found 260 image URLs for category: boat
# Scraping category: traffic
# Scraping URL: https://unsplash.com/s/photos/traffic
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: traffic
# No new unique URLs to add.
# Scraping category: light
# Scraping URL: https://unsplash.com/s/photos/light
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: light
# Scraping category: fire hydrant
# Scraping URL: https://unsplash.com/s/photos/fire hydrant
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 320 image URLs.
# Found 320 image URLs for category: fire hydrant
# Scraping category: stop sign
# Scraping URL: https://unsplash.com/s/photos/stop sign
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: stop sign
# Scraping category: parking meter
# Scraping URL: https://unsplash.com/s/photos/parking meter
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: parking meter
# Scraping category: bench
# Scraping URL: https://unsplash.com/s/photos/bench
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: bench
# Scraping category: bird
# Scraping URL: https://unsplash.com/s/photos/bird
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 320 image URLs.
# Found 320 image URLs for category: bird
# Scraping category: cat
# Scraping URL: https://unsplash.com/s/photos/cat
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: cat
# Scraping category: dog
# Scraping URL: https://unsplash.com/s/photos/dog
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: dog
# Scraping category: horse
# Scraping URL: https://unsplash.com/s/photos/horse
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: horse
# Scraping category: sheep
# Scraping URL: https://unsplash.com/s/photos/sheep
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 80 image URLs.
# Found 80 image URLs for category: sheep
# No new unique URLs to add.
# Scraping category: cow
# Scraping URL: https://unsplash.com/s/photos/cow
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: cow
# Scraping category: elephant
# Scraping URL: https://unsplash.com/s/photos/elephant
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 260 image URLs.
# Found 260 image URLs for category: elephant
# Scraping category: bear
# Scraping URL: https://unsplash.com/s/photos/bear
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: bear
# Scraping category: zebra
# Scraping URL: https://unsplash.com/s/photos/zebra
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 180 image URLs.
# Found 180 image URLs for category: zebra
# No new unique URLs to add.
# Scraping category: giraffe
# Scraping URL: https://unsplash.com/s/photos/giraffe
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: giraffe
# Scraping category: backpack
# Scraping URL: https://unsplash.com/s/photos/backpack
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 260 image URLs.
# Found 260 image URLs for category: backpack
# Scraping category: umbrella
# Scraping URL: https://unsplash.com/s/photos/umbrella
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 320 image URLs.
# Found 320 image URLs for category: umbrella
# Scraping category: handbag
# Scraping URL: https://unsplash.com/s/photos/handbag
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: handbag
# Scraping category: tie
# Scraping URL: https://unsplash.com/s/photos/tie
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: tie
# No new unique URLs to add.
# Scraping category: suitcase
# Scraping URL: https://unsplash.com/s/photos/suitcase
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 180 image URLs.
# Found 180 image URLs for category: suitcase
# Scraping category: frisbee
# Scraping URL: https://unsplash.com/s/photos/frisbee
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: frisbee
# Scraping category: skis
# Scraping URL: https://unsplash.com/s/photos/skis
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: skis
# Scraping category: snowboard
# Scraping URL: https://unsplash.com/s/photos/snowboard
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 100 image URLs.
# Found 100 image URLs for category: snowboard
# No new unique URLs to add.
# Scraping category: sports ball
# Scraping URL: https://unsplash.com/s/photos/sports ball
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: sports ball
# No new unique URLs to add.
# Scraping category: kite
# Scraping URL: https://unsplash.com/s/photos/kite
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: kite
# Scraping category: baseball bat
# Scraping URL: https://unsplash.com/s/photos/baseball bat
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 160 image URLs.
# Found 160 image URLs for category: baseball bat
# Scraping category: baseball glove
# Scraping URL: https://unsplash.com/s/photos/baseball glove
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 180 image URLs.
# Found 180 image URLs for category: baseball glove
# Scraping category: skateboard
# Scraping URL: https://unsplash.com/s/photos/skateboard
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 200 image URLs.
# Found 200 image URLs for category: skateboard
# Scraping category: surfboard
# Scraping URL: https://unsplash.com/s/photos/surfboard
# ...
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: cell phone
# Scraping category: microwave
# Scraping URL: https://unsplash.com/s/photos/microwave
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: microwave
# Scraping category: oven
# Scraping URL: https://unsplash.com/s/photos/oven
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 280 image URLs.
# Found 280 image URLs for category: oven
# Scraping category: toaster
# Scraping URL: https://unsplash.com/s/photos/toaster
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 160 image URLs.
# Found 160 image URLs for category: toaster
# Scraping category: sink
# Scraping URL: https://unsplash.com/s/photos/sink
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 200 image URLs.
# Found 200 image URLs for category: sink
# Scraping category: refrigerator
# Scraping URL: https://unsplash.com/s/photos/refrigerator
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 140 image URLs.
# Found 140 image URLs for category: refrigerator
# Scraping category: book
# Scraping URL: https://unsplash.com/s/photos/book
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 260 image URLs.
# Found 260 image URLs for category: book
# Scraping category: clock
# Scraping URL: https://unsplash.com/s/photos/clock
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: clock
# Scraping category: vase
# Scraping URL: https://unsplash.com/s/photos/vase
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: vase
# Scraping category: scissors
# Scraping URL: https://unsplash.com/s/photos/scissors
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 220 image URLs.
# Found 220 image URLs for category: scissors
# Scraping category: teddy bear
# Scraping URL: https://unsplash.com/s/photos/teddy bear
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 160 image URLs.
# Found 160 image URLs for category: teddy bear
# Scraping category: hair drier
# Scraping URL: https://unsplash.com/s/photos/hair drier
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 300 image URLs.
# Found 300 image URLs for category: hair drier
# Scraping category: toothbrush
# Scraping URL: https://unsplash.com/s/photos/toothbrush
# Clicked 'Load more' on scroll 1
# Scrolled 1 times.
# No 'Load more' button after scroll 2 or already clicked.
# Scrolled 2 times.
# No 'Load more' button after scroll 3 or already clicked.
# Scrolled 3 times.
# No 'Load more' button after scroll 4 or already clicked.
# Scrolled 4 times.
# No 'Load more' button after scroll 5 or already clicked.
# Scrolled 5 times.
# No 'Load more' button after scroll 6 or already clicked.
# Scrolled 6 times.
# No 'Load more' button after scroll 7 or already clicked.
# Scrolled 7 times.
# No 'Load more' button after scroll 8 or already clicked.
# Scrolled 8 times.
# No 'Load more' button after scroll 9 or already clicked.
# Scrolled 9 times.
# No 'Load more' button after scroll 10 or already clicked.
# Scrolled 10 times.
# No 'Load more' button after scroll 11 or already clicked.
# Scrolled 11 times.
# No 'Load more' button after scroll 12 or already clicked.
# Scrolled 12 times.
# No 'Load more' button after scroll 13 or already clicked.
# Scrolled 13 times.
# No 'Load more' button after scroll 14 or already clicked.
# Scrolled 14 times.
# No 'Load more' button after scroll 15 or already clicked.
# Scrolled 15 times.
# Found 240 image URLs.
# Found 240 image URLs for category: toothbrush
